# %%
import json
records={
        1001:{"Name":"chocoalte","Price":10,"Quantity":100},
        1002:{"Name":"chocoalte Cake","Price":100,"Quantity":10},
        1003:{"Name":"Milky Bar","Price":20,"Quantity":80},
        1004:{"Name":"borbourn","Price":35,"Quantity":200},
        }
# records

# %%
#print Menu
print('----------------MENU------------------')
for items in records:
    print( items,":",records[items]['Name'],records[items]['Price'], records[items]['Quantity'] )
    ui_item = input("Enter id of product: ")
    ui_quantity= input("Enter the quantity: ")
print('-----------------BILL------------------')
     print(records[ui_item]
# Out:
# ----------------MENU------------------
# 1001 : chocoalte 10 100
# 1002 : chocoalte Cake 100 10
# 1003 : Milky Bar 20 80
# 1004 : borbourn 35 200

# %%
js = json.dumps(records)
fd = open('inventory.json','w')
fd.write(js)
fd.close()

fd = open('inventory.json','r')
info = fd.read()
fd.close()
js = json.loads(info) #converts json into python object 
for key in js:
    print(js[key]['Name'])
# Out:
# chocoalte
# chocoalte Cake
# Milky Bar
# borbourn
