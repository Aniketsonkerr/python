# %%
import json
fd = open('inventory.json','r')
records=fd.read()
fd.close()

js = json.loads(records)

print('---------------MENU----------------')
for key in js:
    print(key,js[key]['Name'],js[key]['Price'],js[key]['Quantity'])
item_id=input('enter item id: ')
item_qt=int(input('enter item quantity: '))
if(js[item_id]['Quantity']<item_qt):
    if(input(f"we have {js[item_id]['Quantity']} would you like to purchase them all ?if yes, enter 'yes': ") == 'yes'):
       print('---------------BILL----------------')
       print(
    else:
       print("Invalid input, please enter 'yes' or 'no'.")
# Out:
# ---------------MENU----------------
# 1001 chocoalte 10 100
# 1002 chocoalte Cake 100 10
# 1003 Milky Bar 20 80
# 1004 borbourn 35 200
# enter item id:  1001
# enter item quantity:  103
# we have 100would you like to purchase them all ?if yes, enter 'yes':  yes
# ---------------BILL----------------
